# %% [markdown]
# ## Bike Sharing Demand - Analysis and Visualization

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ### Load and Preview Data

# %%
train_df = pd.read_csv('data/train.csv')
test_df = pd.read_csv('data/test.csv')
print('Train Data Shape: ', train_df.shape)
print('Test Data Shape: ', test_df.shape)
# Out:
# Train Data Shape:  (10886, 12)
# Test Data Shape:  (6493, 9)

# %%
train_df.head()
# Out:
#               datetime  season  holiday  workingday  weather  temp   atemp  \
# 0  2011-01-01 00:00:00       1        0           0        1  9.84  14.395
# 1  2011-01-01 01:00:00       1        0           0        1  9.02  13.635
# 2  2011-01-01 02:00:00       1        0           0        1  9.02  13.635
# 3  2011-01-01 03:00:00       1        0           0        1  9.84  14.395
# 4  2011-01-01 04:00:00       1        0           0        1  9.84  14.395
#
#    humidity  windspeed  casual  registered  count
# 0        81        0.0       3          13     16
# 1        80        0.0       8          32     40
# 2        80        0.0       5          27     32
# 3        75        0.0       3          10     13
# 4        75        0.0       0           1      1

# %%
test_df.head()
# Out:
#               datetime  season  holiday  workingday  weather   temp   atemp  \
# 0  2011-01-20 00:00:00       1        0           1        1  10.66  11.365
# 1  2011-01-20 01:00:00       1        0           1        1  10.66  13.635
# 2  2011-01-20 02:00:00       1        0           1        1  10.66  13.635
# 3  2011-01-20 03:00:00       1        0           1        1  10.66  12.880
# 4  2011-01-20 04:00:00       1        0           1        1  10.66  12.880
#
#    humidity  windspeed
# 0        56    26.0027
# 1        56     0.0000
# 2        56     0.0000
# 3        56    11.0014
# 4        56    11.0014

# %% [markdown]
# ### Transform Data

# %%
def season_map(x):
    seasons = ['spring','summer','fall','winter']
    return seasons[x-1]

def weather_map(x):
    weather = ['clear','mist','light_rain','heavy_rain']
    return weather[x-1]

train_df['season'] = train_df['season'].map(season_map)
train_df['weather'] = train_df['weather'].map(weather_map)
train_df['hour'] = train_df['datetime'].apply(lambda x: pd.to_datetime(x).hour)
train_df[['round_temp','round_atemp']] = train_df[['temp','atemp']].apply(lambda x: round(x))
train_df[['round_humidity','round_windspeed']] = train_df[['humidity','windspeed']].apply(lambda x: round(x,-1))
train_df = train_df.rename(columns={'count':'both'})
train_df.head()
# Out:
#               datetime  season  holiday  workingday weather  temp   atemp  \
# 0  2011-01-01 00:00:00  spring        0           0   clear  9.84  14.395
# 1  2011-01-01 01:00:00  spring        0           0   clear  9.02  13.635
# 2  2011-01-01 02:00:00  spring        0           0   clear  9.02  13.635
# 3  2011-01-01 03:00:00  spring        0           0   clear  9.84  14.395
# 4  2011-01-01 04:00:00  spring        0           0   clear  9.84  14.395
#
#    humidity  windspeed  casual  registered  both  hour  round_temp  \
# 0        81        0.0       3          13    16     0        10.0
# 1        80        0.0       8          32    40     1         9.0
# 2        80        0.0       5          27    32     2         9.0
# 3        75        0.0       3          10    13     3        10.0
# 4        75        0.0       0           1     1     4        10.0
#
#    round_atemp  round_humidity  round_windspeed
# 0         14.0              80              0.0
# 1         14.0              80              0.0
# 2         14.0              80              0.0
# 3         14.0              80              0.0
# 4         14.0              80              0.0

# %% [markdown]
# ### Data Exploration

# %%
# First see distribution of rentals only by hour.
counts = ['casual','registered','both'] # All 3 variables we would like to predict.
hour_train_df = train_df[['hour'] + counts].groupby('hour').mean()
hour_train_df.plot()
plt.xlabel('Hour')
plt.ylabel('Average Rentals Per Hour')
plt.title('Bike Rentals')
plt.show()

# %% [markdown]
# We see the most popular times are in morning hours and after work. Those registered follow a more particular distribution.

# %%
# See distribution of rentals by season.
seasons_train_df = train_df[['season'] + counts].groupby('season').mean()
seasons_train_df.plot.bar()
plt.xlabel('Season')
plt.ylabel('Average Rentals Per Hour')
plt.title('Bike Rentals')
plt.show()

# %%
# Distribution by weather.
weather_train_df = train_df[['weather'] + counts].groupby('weather').mean()
weather_train_df.plot.bar()
plt.xlabel('Weather')
plt.ylabel('Average Rentals Per Hour')
plt.title('Bike Rentals')
plt.show()

# %%
# Mean of heavy_rain days was abnormally high, investigate why.
heavy_rain_df = train_df[train_df['weather'] == 'heavy_rain']
heavy_rain_df
# Out:
#                  datetime  season  holiday  workingday     weather  temp  \
# 5631  2012-01-09 18:00:00  spring        0           1  heavy_rain   8.2
#
#        atemp  humidity  windspeed  casual  registered  both  hour  round_temp  \
# 5631  11.365        86     6.0032       6         158   164    18         8.0
#
#       round_atemp  round_humidity  round_windspeed
# 5631         11.0              90             10.0

# %% [markdown]
# We see only one hour of heavy rain exists, and it has a high count!

# %%
# By holiday / workday.
days = ['holiday','workingday']
work_train_df = train_df[days + counts].groupby(days).mean().reset_index()
work_train_df.plot.bar(x=days)
plt.xlabel('(Holiday, Working Day)')
plt.ylabel('Average Rentals Per Hour')
plt.title('Bike Rentals')
plt.show()

# %% [markdown]
# Doesn't seem to make a difference if working day or holiday.

# %%
# By season, weather, and hour, sorted. Discover which yield the highest rates.
cols = ['season','weather','hour']
combined_train_df = train_df[cols + counts].groupby(cols).mean().reset_index().sort_values('both', ascending=False)
combined_train_df
# Out:
#      season     weather  hour      casual  registered        both
# 17     fall       clear    17  112.500000  491.182927  603.682927
# 162  summer       clear    17  103.812500  482.337500  586.150000
# 18     fall       clear    18  100.987654  465.839506  566.827160
# 65     fall        mist    17  102.666667  451.222222  553.888889
# 163  summer       clear    18   91.307692  452.769231  544.076923
# 66     fall        mist    18   87.818182  440.681818  528.500000
# 234  winter       clear    17   67.407895  447.736842  515.144737
# 210  summer        mist    17  120.869565  365.521739  486.391304
# 282  winter        mist    17   42.416667  429.791667  472.208333
# 283  winter        mist    18   31.461538  440.615385  472.076923
# 273  winter        mist     8   16.977778  433.288889  450.266667
# 56     fall        mist     8   33.551724  412.965517  446.517241
# 19     fall       clear    19   88.000000  351.517647  439.517647
# 235  winter       clear    18   47.118421  388.460526  435.578947
# 201  summer        mist     8   26.631579  403.289474  429.921053
# 211  summer        mist    18   92.520000  319.240000  411.760000
# 64     fall        mist    16  115.100000  295.550000  410.650000
# 225  winter       clear     8   19.550000  382.450000  402.000000
# 164  summer       clear    19   72.771084  327.867470  400.638554
# 153  summer       clear     8   29.492308  366.230769  395.723077
# 8      fall       clear     8   33.594937  360.215190  393.810127
# 187  summer  light_rain    18   42.454545  340.727273  383.181818
# 16     fall       clear    16  101.452381  278.928571  380.380952
# 67     fall        mist    19   74.904762  300.095238  375.000000
# 161  summer       clear    16   96.817073  274.329268  371.146341
# 233  winter       clear    16   76.246753  294.246753  370.493506
# 41     fall  light_rain    17   77.785714  278.071429  355.857143
# 42     fall  light_rain    18   52.181818  303.636364  355.818182
# 209  summer        mist    16  115.480000  239.920000  355.400000
# 258  winter  light_rain    17   34.214286  316.428571  350.642857
# ..      ...         ...   ...         ...         ...         ...
# 243  winter  light_rain     2    3.500000   10.000000   13.500000
# 170  summer  light_rain     1    3.777778    8.777778   12.555556
# 268  winter        mist     3    2.361111   10.111111   12.472222
# 148  summer       clear     3    3.306667    8.480000   11.786667
# 74   spring       clear     2    2.030769    9.123077   11.153846
# 220  winter       clear     3    1.985714    9.114286   11.100000
# 77   spring       clear     5    0.376812   10.275362   10.652174
# 97   spring  light_rain     0    0.500000    9.375000    9.875000
# 126  spring        mist     5    0.466667    9.266667    9.733333
# 102  spring  light_rain     5    0.272727    9.363636    9.636364
# 99   spring  light_rain     2    1.363636    8.272727    9.636364
# 52     fall        mist     4    2.083333    7.208333    9.291667
# 27     fall  light_rain     3    1.500000    7.500000    9.000000
# 124  spring        mist     3    1.035714    7.214286    8.250000
# 269  winter        mist     4    1.394737    6.789474    8.184211
# 4      fall       clear     4    1.614458    6.409639    8.024096
# 75   spring       clear     3    1.491803    6.278689    7.770492
# 221  winter       clear     4    1.042857    5.857143    6.900000
# 149  summer       clear     4    1.630137    5.260274    6.890411
# 197  summer        mist     4    1.464286    5.250000    6.714286
# 171  summer  light_rain     2    1.111111    4.888889    6.000000
# 100  spring  light_rain     3    0.571429    5.142857    5.714286
# 245  winter  light_rain     4    0.666667    4.333333    5.000000
# 172  summer  light_rain     3    1.222222    3.666667    4.888889
# 173  summer  light_rain     4    1.500000    3.333333    4.833333
# 28     fall  light_rain     4    1.142857    3.571429    4.714286
# 244  winter  light_rain     3    1.000000    3.166667    4.166667
# 125  spring        mist     4    0.518519    2.925926    3.444444
# 76   spring       clear     4    0.666667    2.761905    3.428571
# 101  spring  light_rain     4    0.181818    2.363636    2.545455
#
# [289 rows x 6 columns]

# %% [markdown]
# We see the peak situations for bike rentals: Clear summer and fall days after work.

# %%
# Temperature
temp_train_df = train_df[['round_temp'] + counts].groupby('round_temp').mean()
atemp_train_df = train_df[['round_atemp'] + counts].groupby('round_atemp').mean()
fig, axs = plt.subplots(2,1)
temp_train_df.plot(ax=axs[0])
atemp_train_df.plot(ax=axs[1])
plt.xlabel('1) Temperature 2) Felt Temperature')
plt.ylabel('Average Rentals Per Hour')
plt.show()

# %%
# Try using scatter plots.
sns.pairplot(train_df, x_vars=['temp','atemp'], y_vars='both', size=7, aspect=0.7)
plt.show()

# %% [markdown]
# Generally, the higher temperature the better, but the relationship isn't that strong. Also, not a huge difference between temperature and felt temperature overall.

# %%
# Humidity
humidity_train_df = train_df[['round_humidity'] + counts].groupby('round_humidity').mean()
humidity_train_df.plot()
plt.xlabel('Humidity')
plt.ylabel('Average Rentals Per Hour')
plt.title('Bike Rentals')
plt.show()

# %% [markdown]
# Too dry is very bad for rentals? Should investigate. As expected, too wet is bad as well, but drops off steadily.

# %%
low_humidity_df = train_df[train_df['humidity'] < 15]
low_humidity_df
# Out:
#                  datetime  season  holiday  workingday     weather   temp  \
# 851   2011-02-18 22:00:00  spring        0           1       clear  22.14
# 852   2011-02-18 23:00:00  spring        0           1       clear  21.32
# 853   2011-02-19 00:00:00  spring        0           0       clear  19.68
# 854   2011-02-19 01:00:00  spring        0           0       clear  18.86
# 855   2011-02-19 02:00:00  spring        0           0       clear  18.04
# 856   2011-02-19 03:00:00  spring        0           0       clear  17.22
# 1091  2011-03-10 00:00:00  spring        0           1  light_rain  13.94
# 1092  2011-03-10 01:00:00  spring        0           1  light_rain  13.94
# 1093  2011-03-10 02:00:00  spring        0           1  light_rain  13.94
# 1094  2011-03-10 05:00:00  spring        0           1  light_rain  14.76
# 1095  2011-03-10 06:00:00  spring        0           1  light_rain  14.76
# 1096  2011-03-10 07:00:00  spring        0           1  light_rain  15.58
# 1097  2011-03-10 08:00:00  spring        0           1  light_rain  15.58
# 1098  2011-03-10 09:00:00  spring        0           1  light_rain  16.40
# 1099  2011-03-10 10:00:00  spring        0           1  light_rain  16.40
# 1100  2011-03-10 11:00:00  spring        0           1  light_rain  16.40
# 1101  2011-03-10 12:00:00  spring        0           1  light_rain  17.22
# 1102  2011-03-10 13:00:00  spring        0           1  light_rain  17.22
# 1103  2011-03-10 14:00:00  spring        0           1  light_rain  18.04
# 1104  2011-03-10 15:00:00  spring        0           1  light_rain  18.04
# 1105  2011-03-10 16:00:00  spring        0           1  light_rain  17.22
# 1106  2011-03-10 17:00:00  spring        0           1        mist  18.04
# 1107  2011-03-10 18:00:00  spring        0           1  light_rain  18.04
# 1108  2011-03-10 19:00:00  spring        0           1  light_rain  18.04
# 1109  2011-03-10 20:00:00  spring        0           1  light_rain  14.76
# 1110  2011-03-10 21:00:00  spring        0           1  light_rain  14.76
# 1111  2011-03-10 22:00:00  spring        0           1        mist  13.94
# 1112  2011-03-10 23:00:00  spring        0           1  light_rain  13.94
#
#        atemp  humidity  windspeed  casual  registered  both  hour  round_temp  \
# 851   25.760        10    16.9979      19          88   107    22        22.0
# 852   25.000         8    19.0012      16          61    77    23        21.0
# 853   23.485        12    32.9975       6          23    29     0        20.0
# 854   22.725        14    27.9993      10          21    31     1        19.0
# 855   21.970        13    26.0027       3          14    17     2        18.0
# 856   21.210        14    19.9995       0           7     7     3        17.0
# 1091  15.910         0    16.9979       3           0     3     0        14.0
# 1092  15.910         0    16.9979       0           2     2     1        14.0
# 1093  15.910         0    16.9979       0           1     1     2        14.0
# 1094  17.425         0    12.9980       1           2     3     5        15.0
# 1095  16.665         0    22.0028       0          12    12     6        15.0
# 1096  19.695         0    15.0013       1          36    37     7        16.0
# 1097  19.695         0    19.0012       1          43    44     8        16.0
# 1098  20.455         0    15.0013       1          23    24     9        16.0
# 1099  20.455         0    11.0014       0          17    17    10        16.0
# 1100  20.455         0    16.9979       6           5    11    11        16.0
# 1101  21.210         0    15.0013       4          30    34    12        17.0
# 1102  21.210         0    15.0013       1          11    12    13        17.0
# 1103  21.970         0    19.9995       0          12    12    14        18.0
# 1104  21.970         0    15.0013       3          11    14    15        18.0
# 1105  21.210         0    16.9979       1          20    21    16        17.0
# 1106  21.970         0    26.0027       2         109   111    17        18.0
# 1107  21.970         0    23.9994       2          80    82    18        18.0
# 1108  21.970         0    39.0007       5          51    56    19        18.0
# 1109  16.665         0    22.0028       9          29    38    20        15.0
# 1110  17.425         0    15.0013       1          27    28    21        15.0
# 1111  16.665         0     8.9981       4          30    34    22        14.0
# 1112  17.425         0     6.0032       1          26    27    23        14.0
#
#       round_atemp  round_humidity  round_windspeed
# 851          26.0              10             20.0
# 852          25.0              10             20.0
# 853          23.0              10             30.0
# 854          23.0              10             30.0
# 855          22.0              10             30.0
# 856          21.0              10             20.0
# 1091         16.0               0             20.0
# 1092         16.0               0             20.0
# 1093         16.0               0             20.0
# 1094         17.0               0             10.0
# 1095         17.0               0             20.0
# 1096         20.0               0             20.0
# 1097         20.0               0             20.0
# 1098         20.0               0             20.0
# 1099         20.0               0             10.0
# 1100         20.0               0             20.0
# 1101         21.0               0             20.0
# 1102         21.0               0             20.0
# 1103         22.0               0             20.0
# 1104         22.0               0             20.0
# 1105         21.0               0             20.0
# 1106         22.0               0             30.0
# 1107         22.0               0             20.0
# 1108         22.0               0             40.0
# 1109         17.0               0             20.0
# 1110         17.0               0             20.0
# 1111         17.0               0             10.0
# 1112         17.0               0             10.0

# %% [markdown]
# Many of these days of light rain have zero humidity? Let's see the distribution of weather and humidity.

# %%
cols = ['round_humidity','weather']
humidity_weather_train_df = train_df[cols + ['both']].groupby(cols).count().rename(columns={'both':'Number of Hours'})
humidity_weather_train_df
# Out:
#                            Number of Hours
# round_humidity weather
# 0              light_rain               20
#                mist                      2
# 10             clear                     6
# 20             clear                   180
#                mist                     10
# 30             clear                   565
#                mist                     50
# 40             clear                  1376
#                light_rain               11
#                mist                    222
# 50             clear                  1295
#                light_rain               23
#                mist                    357
# 60             clear                  1395
#                light_rain               57
#                mist                    525
# 70             clear                  1021
#                light_rain               82
#                mist                    485
# 80             clear                   935
#                light_rain              204
#                mist                    532
# 90             clear                   410
#                heavy_rain                1
#                light_rain              381
#                mist                    591
# 100            clear                     9
#                light_rain               81
#                mist                     60

# %% [markdown]
# Very strange that there are 20 light rain occurrences at close to zero humidity...

# %%
# Windspeed
windspeed_train_df = train_df[['round_windspeed'] + counts].groupby('round_windspeed').mean()
windspeed_train_df.plot()
plt.xlabel('Windspeed')
plt.ylabel('Average Rentals Per Hour')
plt.title('Bike Rentals')
plt.show()

# %%
# Strange pattern. Investigate!
high_wind_df = train_df[train_df['windspeed'] > 45]
high_wind_df = high_wind_df[['windspeed','hour','both']].sort_values('windspeed')
high_wind_df
# Out:
#       windspeed  hour  both
# 761     46.0022     2     3
# 6141    46.0022     3    14
# 6513    46.0022    15   185
# 6142    47.9988     4     1
# 6988    47.9988    12   280
# 868     50.0021    15   171
# 760     51.9987     1     5
# 2755    56.9969    17   358
# 2756    56.9969    18   181

# %% [markdown]
# Inconsistency is just due to small sample size. Should account for differences in time in the average.

# %%
# Windspeed during daytime.
daytime_df = train_df[(train_df['hour'] > 7) & (train_df['hour'] < 21)]
windspeed2_train_df = daytime_df[['round_windspeed'] + counts].groupby('round_windspeed').mean()
windspeed2_train_df.plot()
plt.xlabel('Windspeed')
plt.ylabel('Average Rentals Per Hour, 8 AM - 8 PM')
plt.title('Bike Rentals')
plt.show()

# %% [markdown]
# Inconsistency is somewhat smoothed out.
